# %%
z=True
while z:
    print("There Are 10 Websites To Find A Doctor")
    print("This Program Shows You The Categories Of the Doctors Chose Which One Is Best For You :)")
    a=("http://doctorshospital.com.pk/our-doctors")
    print("a",a)
    b=("https://healthwire.pk")
    print("b",b)
    c=("https://www.icliniq.com/doctors-by-country/PK/Pakistan")
    print("c",c)
    d=("https://healthonline.pk/doctor-directory/doctor")
    print("d",d)
    e=("https://www.lybrate.com")
    print("e",e)
    f=("https://www.healthgrades.com")
    print("f",f)
    g=("https://www.marham.pk")
    print("g",g)
    h=("https://www.askapollo.com/physical-appointment")
    print("h",h)
    i=("https://www.ohiohealth.com/find-a-doctor")
    print("i",i)
    j=("http://edition.cnn.com/HEALTH/health.a.z")
    print("j",j)
    x=("Press x to Close The Program")
    print("x",x)
    
    #Extra https://hospitals.aku.edu/pakistan/Pages/Find-a-Doctor.aspx
    choice = input("Enter Your Choice : ")
    if choice == "a":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("http://doctorshospital.com.pk/our-doctors")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="col-md-12"):
            for link in atag.find_all('a'):
                print(link.get('href'))
    elif choice == "b":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://healthwire.pk")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="wrapper"):
            for link in atag.find_all('a'):
                print(link.get('category-grid'))
                print(link.get('href'))
    elif choice == "c":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://www.icliniq.com/doctors-by-country/PK/Pakistan")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="col-md-8"):
            for link in atag.find_all('a'):
                print(link.get('divDocRow corner'))
                print(link.get('href'))
    elif choice == "d":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://healthonline.pk/doctor-directory/doctor")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="cbp-item"):
            for link in atag.find_all('a'):
                print(link.get('href'))
    elif choice == "e":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://www.lybrate.com")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="col-xs-12 a-topCategories"):
            for link in atag.find_all('a'):
                print(link.get('href'))
    elif choice == "f":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://www.marham.pk")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="category-widget"):
            for link in atag.find_all('a'):
                print(link.get('href'))

    elif choice == "g":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("http://www.shifa.com.pk/find-doctor")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="footer-widget widget_wpex_port_posts_thumb_widget clr"):
            for link in atag.find_all('a'):
                print(link.get('href'))
    elif choice == "h":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://www.askapollo.com/physical-appointment")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="row"):
            for link in atag.find_all('a'):
                print(link.get('href'))

    elif choice == "i":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("https://www.ohiohealth.com/find-a-doctor")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="column small-12 medium-6 large-3 commonly-searched--terms-items "):
            for link in atag.find_all('a'):
                print(link.get('href'))

    elif choice == "j":
        from bs4 import BeautifulSoup
        import requests
        r  = requests.get("http://edition.cnn.com/HEALTH/health.a.z")
        data = r.text
        soup = BeautifulSoup(data,'html.parser')
        for atag in soup.find_all("div", class_="cnnPopHealthTopicsc1"):
            for link in atag.find_all('a'):
                print(link.get('href'))
    elif choice =='x':
        break


    print("Doctors With Their Categories Are Above :)")
    print("")
# Out:
# There Are 10 Websites To Find A Doctor
# This Program Shows You The Categories Of the Doctors Chose Which One Is Best For You :)
# a http://doctorshospital.com.pk/our-doctors
# b https://healthwire.pk
# c https://www.icliniq.com/doctors-by-country/PK/Pakistan
# d https://healthonline.pk/doctor-directory/doctor
# e https://www.lybrate.com
# f https://www.healthgrades.com
# g https://www.marham.pk
# h https://www.askapollo.com/physical-appointment
# i https://www.ohiohealth.com/find-a-doctor
# j http://edition.cnn.com/HEALTH/health.a.z
# x Press x to Close The Program
# Enter Your Choice : a
# http://doctorshospital.com.pk/
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# http://doctorshospital.com.pk/wp-content/uploads/2016/03/dr.kamran-butt.jpg
# http://doctorshospital.com.pk/mdoc/1989/
# ...
